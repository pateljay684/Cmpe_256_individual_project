# %%
from sklearn.feature_extraction.text import CountVectorizer
from nltk.stem import PorterStemmer
from nltk.corpus import stopwords
from nltk.tokenize import RegexpTokenizer
from nltk.stem import WordNetLemmatizer
from sklearn.neighbors import NearestNeighbors
from sklearn.metrics.pairwise import linear_kernel
from sklearn.metrics.pairwise import euclidean_distances
from sklearn.neighbors import DistanceMetric
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import pandas as pd
import nltk
import numpy as np

# %% [markdown]
# loading data

# %%
colnames = ['course_id','course_name', 'link', 'course_details']
data = pd.read_csv('courses.csv',skiprows=[0],names=colnames)
data
# Out:
#     course_id                                        course_name  \
# 0    CMPE 030               Programming Concepts and Methodology
# 1    CMPE 050           Object-Oriented Concepts and Methodology
# 2    CMPE 102                      Assembly Language Programming
# 3    CMPE 110                  Electronics for Computing Systems
# 4    CMPE 120             Computer Organization and Architecture
# 5    CMPE 124                                   Digital Design I
# 6    CMPE 125                                  Digital Design II
# 7    CMPE 126               Algorithms and Data Structure Design
# 8    CMPE 127                            Microprocessor Design I
# 9    CMPE 130                          Advanced Algorithm Design
# 10   CMPE 131                             Software Engineering I
# 11   CMPE 132                               Information Security
# 12   CMPE 133                            Software Engineering II
# 13   CMPE 135                Object-Oriented Analysis and Design
# 14   CMPE 137               Wireless Mobile Software Engineering
# 15   CMPE 138                                 Database Systems I
# 16   CMPE 139                        Fundamentals of Data Mining
# 17   CMPE 140                   Computer Architecture and Design
# 18   CMPE 142                           Operating Systems Design
# 19   CMPE 146                Real-Time Embedded System Co-Design
# 20   CMPE 147        Fundamentals of System on Chip (SoC) Design
# 21   CMPE 148                                Computer Networks I
# 22   CMPE 150  System Architecture and Electronic Design for ...
# 23   CMPE 152                                    Compiler Design
# 24   CMPE 163  Introduction to Computer Graphics and Augmente...
# 25   CMPE 165            Software Engineering Process Management
# 26   CMPE 172                      Enterprise Software Platforms
# 27  CMPE 180A              Data Structures and Algorithms in C++
# 28  CMPE 180B                                   Database Systems
# 29  CMPE 180C                           Operating Systems Design
# ..        ...                                                ...
# 51   CMPE 240                           Advanced Computer Design
# 52   CMPE 242                           Embedded Hardware Design
# 53   CMPE 243                      Embedded Systems Applications
# 54   CMPE 244                                  Embedded Software
# 55   CMPE 245                     Embedded Wireless Architecture
# 56   CMPE 246               Interface Design in Embedded Systems
# 57   CMPE 255                                        Data Mining
# 58   CMPE 256                              Large Scale Analytics
# 59   CMPE 257                                   Machine Learning
# 60   CMPE 258                                      Deep Learning
# 61   CMPE 264       Advanced Digital and Computing System Design
# 62   CMPE 265                   High Speed Digital System Design
# 63   CMPE 266                 Big Data Engineering and Analytics
# 64   CMPE 272                      Enterprise Software Platforms
# 65   CMPE 273                     Enterprise Distributed Systems
# 66   CMPE 274                 Business Intelligence Technologies
# 67   CMPE 275                 Enterprise Application Development
# 68   CMPE 277                 Smartphone Application Development
# 69   CMPE 279                     Software Security Technologies
# 70   CMPE 280                      Web UI Design and Development
# 71   CMPE 281                                 Cloud Technologies
# 72   CMPE 282                                     Cloud Services
# 73   CMPE 283                        Virtualization Technologies
# 74   CMPE 284                 Storage and Network Virtualization
# 75   CMPE 285                     Software Engineering Processes
# 76   CMPE 287             Software Quality Assurance and Testing
# 77   CMPE 289                         Cloud Security Engineering
# 78   CMPE 294                       Computer Engineering Seminar
# 79  CMPE 296Y                               High Level Synthesis
# 80  CMPE 296Z                                System Architecture
#
#                                                  link  \
# 0   http://info.sjsu.edu/web-dbgen/catalog/courses...
# 1   http://info.sjsu.edu/web-dbgen/catalog/courses...
# 2   http://info.sjsu.edu/web-dbgen/catalog/courses...
# 3   http://info.sjsu.edu/web-dbgen/catalog/courses...
# 4   http://info.sjsu.edu/web-dbgen/catalog/courses...
# 5   http://info.sjsu.edu/web-dbgen/catalog/courses...
# 6   http://info.sjsu.edu/web-dbgen/catalog/courses...
# 7   http://info.sjsu.edu/web-dbgen/catalog/courses...
# 8   http://info.sjsu.edu/web-dbgen/catalog/courses...
# 9   http://info.sjsu.edu/web-dbgen/catalog/courses...
# 10  http://info.sjsu.edu/web-dbgen/catalog/courses...
# 11  http://info.sjsu.edu/web-dbgen/catalog/courses...
# 12  http://info.sjsu.edu/web-dbgen/catalog/courses...
# 13  http://info.sjsu.edu/web-dbgen/catalog/courses...
# 14  http://info.sjsu.edu/web-dbgen/catalog/courses...
# 15  http://info.sjsu.edu/web-dbgen/catalog/courses...
# 16  http://info.sjsu.edu/web-dbgen/catalog/courses...
# 17  http://info.sjsu.edu/web-dbgen/catalog/courses...
# 18  http://info.sjsu.edu/web-dbgen/catalog/courses...
# 19  http://info.sjsu.edu/web-dbgen/catalog/courses...
# 20  http://info.sjsu.edu/web-dbgen/catalog/courses...
# 21  http://info.sjsu.edu/web-dbgen/catalog/courses...
# 22  http://info.sjsu.edu/web-dbgen/catalog/courses...
# 23  http://info.sjsu.edu/web-dbgen/catalog/courses...
# 24  http://info.sjsu.edu/web-dbgen/catalog/courses...
# 25  http://info.sjsu.edu/web-dbgen/catalog/courses...
# 26  http://info.sjsu.edu/web-dbgen/catalog/courses...
# 27  http://info.sjsu.edu/web-dbgen/catalog/courses...
# 28  http://info.sjsu.edu/web-dbgen/catalog/courses...
# 29  http://info.sjsu.edu/web-dbgen/catalog/courses...
# ..                                                ...
# 51  http://info.sjsu.edu/web-dbgen/catalog/courses...
# 52  http://info.sjsu.edu/web-dbgen/catalog/courses...
# 53  http://info.sjsu.edu/web-dbgen/catalog/courses...
# 54  http://info.sjsu.edu/web-dbgen/catalog/courses...
# 55  http://info.sjsu.edu/web-dbgen/catalog/courses...
# 56  http://info.sjsu.edu/web-dbgen/catalog/courses...
# 57  http://info.sjsu.edu/web-dbgen/catalog/courses...
# 58  http://info.sjsu.edu/web-dbgen/catalog/courses...
# 59  http://info.sjsu.edu/web-dbgen/catalog/courses...
# 60  http://info.sjsu.edu/web-dbgen/catalog/courses...
# 61  http://info.sjsu.edu/web-dbgen/catalog/courses...
# 62  http://info.sjsu.edu/web-dbgen/catalog/courses...
# 63  http://info.sjsu.edu/web-dbgen/catalog/courses...
# 64  http://info.sjsu.edu/web-dbgen/catalog/courses...
# 65  http://info.sjsu.edu/web-dbgen/catalog/courses...
# 66  http://info.sjsu.edu/web-dbgen/catalog/courses...
# 67  http://info.sjsu.edu/web-dbgen/catalog/courses...
# 68  http://info.sjsu.edu/web-dbgen/catalog/courses...
# 69  http://info.sjsu.edu/web-dbgen/catalog/courses...
# 70  http://info.sjsu.edu/web-dbgen/catalog/courses...
# 71  http://info.sjsu.edu/web-dbgen/catalog/courses...
# 72  http://info.sjsu.edu/web-dbgen/catalog/courses...
# 73  http://info.sjsu.edu/web-dbgen/catalog/courses...
# 74  http://info.sjsu.edu/web-dbgen/catalog/courses...
# 75  http://info.sjsu.edu/web-dbgen/catalog/courses...
# 76  http://info.sjsu.edu/web-dbgen/catalog/courses...
# 77  http://info.sjsu.edu/web-dbgen/catalog/courses...
# 78  http://info.sjsu.edu/web-dbgen/catalog/courses...
# 79  http://info.sjsu.edu/web-dbgen/catalog/courses...
# 80  http://info.sjsu.edu/web-dbgen/catalog/courses...
#
#                                        course_details
# 0   Introduction to programming; overview of compu...
# 1   Application of object-oriented software engine...
# 2   Assembly programming; assembly-C interface; CP...
# 3   RC, RL and RLC circuit analysis, diodes and di...
# 4   Introduction to computer organization and arch...
# 5   Combinational and sequential logic theory and ...
# 6   Digital system building blocks, data path and ...
# 7   Object-oriented data organization and represen...
# 8   Microprocessor architecture and assembly langu...
# 9   Design and analysis of data structures and alg...
# 10  Why software engineering? What is software eng...
# 11  A study of computer and network security from ...
# 12  Software Architecture, Software Technical Metr...
# 13  Feasibility analysis and system requirements d...
# 14  Mobility analysis, design principles, techniqu...
# 15  File organization and storage structure, datab...
# 16  Introduction to data management and data minin...
# 17  Pipelining and timing issues in CPU data-paths...
# 18  Overview: history, concepts, system calls and ...
# 19  Embedded system architecture with real-time op...
# 20  System on Chip implementation of a computing s...
# 21  Comparative evaluation of network architecture...
# 22  Design and architecture for generating autonom...
# 23  Principles of lexical analysis, finite state a...
# 24  Introduction to 2D and 3D vector and pixel gra...
# 25  Integrated approach to managing development wi...
# 26  Introduction to enterprise software systems. C...
# 27  Data representation and preprocessing, proximi...
# 28  File organization and storage structure, datab...
# 29  History, concepts, system calls and structures...
# ..                                                ...
# 51  Architecture of a computing system including s...
# 52  dvanced topics dealing with microprocessor and...
# 53  Embedded system interfacing techniques; periph...
# 54  Experiments dealing with advanced embedded sof...
# 55  mbedded wireless architecture with basic commu...
# 56  Oscillator configuration, parallel and serial ...
# 57  Data representation and preprocessing, proximi...
# 58  Data mining and machine learning algorithms an...
# 59  Machine learning concepts, feasibility and lea...
# 60  Deep neural networks and their applications to...
# 61  Advanced topics in register-transfer-level des...
# 62  Introduction to high speed interface design te...
# 63  New big data related technologies, architectur...
# 64  Enterprise software, system and virtualized pl...
# 65  Introduction to application protocols for larg...
# 66  This course covers technologies that are key t...
# 67  Distributed component design, scalability, mes...
# 68  Architectures, technologies, and programming c...
# 69  Fundamental concepts, methods, and tools used ...
# 70  Web User-interface (UI) design and development...
# 71  Cloud computing concepts, evolution, architect...
# 72  Cloud service architecture and layering, admin...
# 73  Virtualization concepts, components and infras...
# 74  Network and storage technologies, network virt...
# 75  Software system development with emerging soft...
# 76  Software testing concepts, processes, models, ...
# 77  Cloud security engineering concepts, issues, i...
# 78  Provides graduate students with a background t...
# 79  Purpose, methodologies, and techniques of high...
# 80  System-level description and verification, per...
#
# [81 rows x 4 columns]

# %% [markdown]
# converting to list

# %%
new_df= data[['course_details']]

col_course_details = data.course_details.tolist ()

col_course_id=data.course_id.tolist()

col_course_name=data.course_name.tolist()
new_df
# Out:
#                                        course_details
# 0   Introduction to programming; overview of compu...
# 1   Application of object-oriented software engine...
# 2   Assembly programming; assembly-C interface; CP...
# 3   RC, RL and RLC circuit analysis, diodes and di...
# 4   Introduction to computer organization and arch...
# 5   Combinational and sequential logic theory and ...
# 6   Digital system building blocks, data path and ...
# 7   Object-oriented data organization and represen...
# 8   Microprocessor architecture and assembly langu...
# 9   Design and analysis of data structures and alg...
# 10  Why software engineering? What is software eng...
# 11  A study of computer and network security from ...
# 12  Software Architecture, Software Technical Metr...
# 13  Feasibility analysis and system requirements d...
# 14  Mobility analysis, design principles, techniqu...
# 15  File organization and storage structure, datab...
# 16  Introduction to data management and data minin...
# 17  Pipelining and timing issues in CPU data-paths...
# 18  Overview: history, concepts, system calls and ...
# 19  Embedded system architecture with real-time op...
# 20  System on Chip implementation of a computing s...
# 21  Comparative evaluation of network architecture...
# 22  Design and architecture for generating autonom...
# 23  Principles of lexical analysis, finite state a...
# 24  Introduction to 2D and 3D vector and pixel gra...
# 25  Integrated approach to managing development wi...
# 26  Introduction to enterprise software systems. C...
# 27  Data representation and preprocessing, proximi...
# 28  File organization and storage structure, datab...
# 29  History, concepts, system calls and structures...
# ..                                                ...
# 51  Architecture of a computing system including s...
# 52  dvanced topics dealing with microprocessor and...
# 53  Embedded system interfacing techniques; periph...
# 54  Experiments dealing with advanced embedded sof...
# 55  mbedded wireless architecture with basic commu...
# 56  Oscillator configuration, parallel and serial ...
# 57  Data representation and preprocessing, proximi...
# 58  Data mining and machine learning algorithms an...
# 59  Machine learning concepts, feasibility and lea...
# 60  Deep neural networks and their applications to...
# 61  Advanced topics in register-transfer-level des...
# 62  Introduction to high speed interface design te...
# 63  New big data related technologies, architectur...
# 64  Enterprise software, system and virtualized pl...
# 65  Introduction to application protocols for larg...
# 66  This course covers technologies that are key t...
# 67  Distributed component design, scalability, mes...
# 68  Architectures, technologies, and programming c...
# 69  Fundamental concepts, methods, and tools used ...
# 70  Web User-interface (UI) design and development...
# 71  Cloud computing concepts, evolution, architect...
# 72  Cloud service architecture and layering, admin...
# 73  Virtualization concepts, components and infras...
# 74  Network and storage technologies, network virt...
# 75  Software system development with emerging soft...
# 76  Software testing concepts, processes, models, ...
# 77  Cloud security engineering concepts, issues, i...
# 78  Provides graduate students with a background t...
# 79  Purpose, methodologies, and techniques of high...
# 80  System-level description and verification, per...
#
# [81 rows x 1 columns]

# %%
pre_processing = ""
pre_processing = pre_processing.join ( col_course_details )

# %% [markdown]
# feature engineering-remove punctuation

# %%
tokenizer = RegexpTokenizer ( r'\w+' )
tokenizer.tokenize ( pre_processing )
sentences = nltk.sent_tokenize ( pre_processing )

# %% [markdown]
# text processing

# %%
stemmer = PorterStemmer ()
for i in range ( len ( sentences ) ):
    wordsStemmer = nltk.word_tokenize ( sentences[i] )
    wordsStemmer = [stemmer.stem ( word ) for word in wordsStemmer]
    sentences[i] = ' '.join ( wordsStemmer )

# %% [markdown]
# text processing two words are same then it will normalization

# %%
lemmatizer = WordNetLemmatizer ()
for i in range ( len ( sentences ) ):
    wordslemmatizer = nltk.word_tokenize ( sentences[i] )
    wordslemmatizer = [lemmatizer.lemmatize ( word ) for word in wordslemmatizer]
    sentences[i] = ' '.join ( wordslemmatizer )

# %% [markdown]
# vector generation

# %%
sentences = sentences[0].split ( '.' )
del sentences[-1]
stopWords = stopwords.words ( 'english' )

vectorizer = CountVectorizer ( stop_words=stopWords )

featurevectors = vectorizer.fit_transform ( col_course_details ).todense ()

# %% [markdown]
# cosine similarity

# %%
def cosine(test2):
    global featurevectors
    cosine_similarities = linear_kernel ( test2, featurevectors ).flatten ()
    related_docs_indices = cosine_similarities.argsort ()[:-5:-1]
    related_docs_indices_list = related_docs_indices.tolist()

    course_name={}
    for i in related_docs_indices:
        course_name[col_course_id[i]]=col_course_name[i]
        
    result = []
    for i in related_docs_indices_list:
        result.append(col_course_details[i])
        
    return (course_name)

# %% [markdown]
# Knn model

# %%
def build_model_knn(test2):
    neigh = NearestNeighbors ( n_neighbors=5 )
    global featurevectors
    neigh.fit ( featurevectors )
    NearestNeighbors ( algorithm='auto', leaf_size=30 )

    final_knn = neigh.kneighbors ( test2, return_distance=False )
    final_knn_list = final_knn.tolist()
    return final_knn_list

# %% [markdown]
# tf-idf

# %%
#getting the data
data_frame = pd.read_csv('courses.csv' , index_col = False)
data_frame = data_frame.loc[:, ~data_frame.columns.str.match('Unnamed')]

new_data_frame= data_frame[['course id','description','name']]


#Making into vectors
tfidfvectorizer = TfidfVectorizer()
tfidfmatrix = tfidfvectorizer.fit_transform(new_data_frame['description'])

data_frame = pd.DataFrame(tfidfmatrix.toarray())

# Caluculating similarity 
cosine_sim = cosine_similarity(data_frame)
df_cosineSim = pd.DataFrame(cosine_sim)

#Recommendations
def recommendations(title, cosine_sim = cosine_sim):
    recommended_course_name={}
    idx = new_data_frame[new_data_frame['description'].str.contains(title, case=False)].index[0]  

    score_series = pd.Series(cosine_sim[idx]).sort_values(ascending = False)

    top_5_indexes = list(score_series.iloc[1:6].index)
    
    for i in top_5_indexes:
        recommended_course_name[list(new_data_frame['course id'])[i]]=(list(new_data_frame['name'])[i])
        
    
    return (recommended_course_name)

# %%
#print(recommendations("cloud computing"))

# %%
input=["software testing"]
vector_input = vectorizer.transform ( input ).toarray ()
build_model_knn ( vector_input )
result_cosine =cosine ( vector_input )
result_tfidf=recommendations(input[0])
#print(result_cosine)
final_output={}
for i in result_cosine:
    if i in result_tfidf:
        final_output[i]=result_tfidf[i]
print(final_output)
# Out:
# {'CMPE 287': 'Software Quality Assurance and Testing', 'CMPE 187': 'Software Quality Engineering', 'CMPE 133': 'Software Engineering II'}
